# %%
import numpy as np
# Visualisation
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
file = r"F:\bmi\DON10795\22-07-30\data\Image_001_001.raw"
data = np.fromfile(file, dtype='uint16')
data = data.reshape(-1,512,512)
mean_frames = np.mean(data[2200:2300], axis=0)
fig = plt.figure(figsize=(20,20))
plt.imshow(mean_frames, vmin=300, vmax=1000, cmap="gray")
plt.axis('off')
fig.savefig("DON-8499_180620_cali.png", dpi=600, bbox_inches='tight')

# %%
plt.plot(np.mean(data, axis=1))
