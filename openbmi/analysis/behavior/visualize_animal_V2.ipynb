# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
#from utils import *

import os

from utils_behavior import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################


#root_dir = r'F:\\bmi\\cohort12'
rooot_dir = '/media/cat/4TB/donato/andres/'
root_dir = '/media/cat/8TB/donato/bmi/master_analysis'

#
animal_id = 'DON-011733'
# animal_id = 'DON-016551'\n",
# animal_id = 'DON-015961'\n",
# animal_id = 'DON-015962'\n",
session_ids = [
    '20230303',
    '20230304',
    '20230305',
    '20230306',
    '20230307',
    '20230308',
    '20230309',

    
]

sessions_early  = [
                '20230303',
                '20230304',
             ]

sess = ProcessSession(root_dir,
                      animal_id)

sess.verbose=False

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()



print ("DONE >..")
# Out:
# Loading n_rewards_per_session.npy
# loading data for n_rewards_per_session:   0%|          | 0/7 [00:00<?, ?it/s]
# loading data for n_rewards_per_session: 100%|██████████| 7/7 [00:00<00:00, 151340.87it/s]
# xx:  [0 1 2 3 4 5 6]
# yy:  [ 45  80  33  17  57 132 123]
# DONE >..

# %%
######################################################
############### SHOW HIT RATES / SESSION #############
######################################################

#
sess.show_plots=True
sess.hit_rate_per_session()

print ("DONE >..")
# Out:
# loading data for hit rate per session:   0%|          | 0/7 [00:00<?, ?it/s]
# loading data for hit rate per session: 100%|██████████| 7/7 [00:00<00:00, 1082.08it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Loading data...
#  14%|█▍        | 1/7 [00:06<00:40,  6.73s/it]
#     ... done loading data...
# Loading data...
#  29%|██▊       | 2/7 [00:13<00:33,  6.74s/it]
#     ... done loading data...
# Loading data...
#  43%|████▎     | 3/7 [00:20<00:26,  6.73s/it]
#     ... done loading data...
# Loading data...
#  57%|█████▋    | 4/7 [00:26<00:20,  6.74s/it]
#     ... done loading data...
# Loading data...
#  71%|███████▏  | 5/7 [00:33<00:13,  6.72s/it]
#     ... done loading data...
# Loading data...
#  86%|████████▌ | 6/7 [00:40<00:06,  6.78s/it]
#     ... done loading data...
# Loading data...
# 100%|██████████| 7/7 [00:47<00:00,  6.76s/it]
#     ... done loading data...

# %%
######################################################
########### EVOLUTION OF CELL-XCORRELOGRAMS ##########
######################################################

#
sess.verbose=False
sess.window = 30   # in seconds
sess.correlograms_inter_session()
# Out:
# loading data for hit rate per session:  14%|█▍        | 1/7 [00:00<00:00,  9.06it/s]
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# loading data for hit rate per session: 100%|██████████| 7/7 [00:00<00:00, 27.97it/s]
# Length of cc:  4 4

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
########################################################
########### CONTINGENCY DEGRADATION PLOTS ##############
########################################################

#
t = [ '20230329',
    '20230330']
cd = [ '20230401',
    '20230402',]
r = [  '20230402',
    '20230403']

sess.pre = t
sess.during = cd
sess.post = r

#
sess.contingency_degradation()

#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       8 cd = [ '20230401',
#       9     '20230402',]
#      10 r = [  '20230402',
#      11     '20230403']
# ---> 13 sess.pre = t
#      14 sess.during = cd
#      15 sess.post = r
#
# NameError: name 'sess' is not defined

# %%
########################################################
########### EARLY VS. LATE PER 5 MIN BLOCK #############
########################################################

#
early = ['20230131',
        '20230201',
        '20230202',
        ]
late = ['20230202',
        '20230203',
        '20230204',
       ]

#
sess.early = early
sess.late = late

#
sess.early_vs_late()

#

# %%
#############################################################
########### EARLY VS. LATE PLOTS - PER SESSION ##############
#############################################################

# same but showing averages per session
sess.early = early
sess.late = late

#
sess.early_vs_late_session()
