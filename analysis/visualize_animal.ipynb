# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################


root_dir = r'F:\bmi\andres\Cohort 7'
#animal_id = 'DON-011733'
animal_id = 'DON-011733'
session_ids = [
    #'20230127',
    #'20230128',
    #'20230129',
    #'20230130',
   '20230303',
    '20230304',
    '20230305',
    '20230306',
    '20230307',
    '20230308',
    '20230309',
    '20230310',
       '20230311'
]


#
sess = ProcessSession(root_dir,
                      animal_id,
                      session_ids[0])

#
sess.verbose=False
sess.session_ids = session_ids

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()

print ("DONE >..")
# Out:
# loading data for n_rewards_per_session: 100%|█████████████████████████████████████████████| 9/9 [01:25<00:00,  9.53s/it]
# xx:  [0 1 2 3 4 5 6 7 8]
# yy:  [ 45  80  33  17  57 132 123  59  26]
# DONE >..

# %%
######################################################
############### SHOW HIT RATES / SESSION #############
######################################################

#
sess.show_plots=True
sess.hit_rate_per_session()

print ("DONE >..")
# Out:
# loading data for hit rate per session: 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 2673.87it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:19<00:00,  2.42s/it]
# Perason corr:  PearsonRResult(statistic=0.6034571654660679, pvalue=0.0647247527066569)

# %%
######################################################
########### EVOLUTION OF CELL-XCORRELOGRAMS ##########
######################################################

#

sess.verbose=False
sess.window = 20*30   # in seconds
sess.correlograms_inter_session()
# Out:
# loading data for hit rate per session:  29%|████████████▌                               | 2/7 [00:00<00:00, 10.28it/s]
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# loading data for hit rate per session: 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 29.60it/s]
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
########################################################
########### CONTINGENCY DEGRADATION PLOTS ##############
########################################################

#
t = ['20230131',
        '20230201']
cd = ['20230202',
        '20230203']
r = ['20230206',
        '20230207']

sess.pre = t
sess.during = cd
sess.post = r

#
sess.contingency_degradation()

#
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 18
#      15 sess.post = r
#      17 #
# ---> 18 sess.contingency_degradation()
#      20 #
#
# File ~/code/bmi/analysis/utils.py:154, in ProcessSession.contingency_degradation(self)
#     152 post = []
#     153 for session_id in self.post:
# --> 154     d = np.load(os.path.join(self.root_dir,
#     155                              self.animal_id,
#     156                              session_id,
#     157                              'results/intra_session_reward_hits_per_minute.npy'
#     158                              ))
#     159     post.append(d.mean())
#     161 #
#
# File ~/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/cat/4TB/donato/andres/Cohort 6 Data/DON-013392/20230207/results/intra_session_reward_hits_per_minute.npy'

# %%
########################################################
########### EARLY VS. LATE PER 5 MIN BLOCK #############
########################################################

#
early = ['20230131',
        '20230201',
        '20230202',
        ]
late = ['20230202',
        '20230203',
        '20230204',
       ]

#
sess.early = early
sess.late = late

#
sess.early_vs_late()

#

# %%
#############################################################
########### EARLY VS. LATE PLOTS - PER SESSION ##############
#############################################################

# same but showing averages per session
sess.early = early
sess.late = late

#
sess.early_vs_late_session()
