# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################

root_dir = '/media/cat/4TB/donato/andres/'
animal_id = 'DON-011733'
session_ids = [
    '20230127',
    '20230128',
    '20230129',
    '20230130',
    '20230131',
    '20230201',
    '20230202',
    '20230203']


#
sess = ProcessSession(root_dir,
                      animal_id,
                      session_ids[0])

#
sess.verbose=False
sess.session_ids = session_ids

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()

print ("DONE >..")
# Out:
# Missing dictionary (early sessions... skipping)
# Missing dictionary (early sessions... skipping)
# Perason corr:  PearsonRResult(statistic=0.6637828397056307, pvalue=0.07266809620684035)
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# Missing dictionary (early sessions... skipping)
# Missing dictionary (early sessions... skipping)
# [array([1, 3, 1, 2, 2, 1, 1, 0, 2, 0]), array([0, 1, 0, 0, 0, 2, 1, 1, 2, 0]), array([ 1,  8,  2,  1, 10,  7,  4,  4, 13,  4]), array([15,  0,  2,  1,  4,  0,  1,  0,  7,  1]), array([ 0,  1, 12,  2,  2,  6,  5,  1,  2,  0]), array([3, 0, 0, 1, 0, 0, 0, 1, 2, 0]), array([ 1,  4, 18,  5,  3,  8,  2,  7,  6,  6]), array([ 1,  4, 10, 16,  9,  8, 11, 13, 13, 13])]
# (8, 10)
# Perason corr:  PearsonRResult(statistic=0.2088699566026267, pvalue=0.5625137721909299)
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
#  25%|████████████████████████▌                                                                         | 2/8 [00:00<00:01,  5.66it/s]
# Missing dictionary (early sessions... skipping)
# Missing dictionary (early sessions... skipping)
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:14<00:00,  1.79s/it]
# Perason corr:  PearsonRResult(statistic=0.23882826950903147, pvalue=0.5063564247744866)

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# DONE >..
