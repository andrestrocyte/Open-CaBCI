# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds

# %%
####################################################
################## LOAD DATA #######################
####################################################


root_dir = '/media/cat/4TB/donato/andres/Cohort 6 Data/'
animal_id = 'DON-013392'
session_ids = [
    #'20230127',
    #'20230128',
    #'20230129',
    #'20230130',
    '20230131',
    '20230201',
    '20230202',
    '20230203',
    '20230204',
    '20230205',
    '20230206',
    '20230207',

]


#
sess = ProcessSession(root_dir,
                      animal_id,
                      session_ids[0])

#
sess.verbose=False
sess.session_ids = session_ids

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()

print ("DONE >..")
# Out:
# Perason corr:  PearsonRResult(statistic=0.6642122365759235, pvalue=0.07241641520254567)
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# [array([0, 0, 0, 1, 0, 3, 3, 2, 4, 4]), array([8, 4, 2, 5, 6, 5, 4, 2, 3, 1]), array([ 3,  9,  7, 11,  5, 12,  7,  8,  7,  6]), array([5, 5, 1, 3, 2, 5, 3, 2, 1, 5]), array([ 1, 15,  8,  7,  5,  5, 17, 16, 16,  7]), array([5, 2, 7, 6, 3, 5, 2, 2, 1, 2]), array([15, 10, 18, 13,  8, 15,  9, 14,  3, 13]), array([ 8,  7, 11, 11,  8, 11, 12,  7, 11,  2])]
# (8, 10)
# Perason corr:  PearsonRResult(statistic=-0.158522371299804, pvalue=0.6618157558553586)
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:19<00:00,  2.42s/it]
# Perason corr:  PearsonRResult(statistic=0.6034571654660679, pvalue=0.0647247527066569)

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
########################################################
########### CONTINGENCY DEGRADATION PLOTS ##############
########################################################

#
t = ['20230131',
        '20230201']
cd = ['20230202',
        '20230203']
r = ['20230206',
        '20230207']

sess.pre = t
sess.during = cd
sess.post = r

#
sess.contingency_degradation()

#
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 18
#      15 sess.post = r
#      17 #
# ---> 18 sess.contingency_degradation()
#      20 #
#
# File ~/code/bmi/analysis/utils.py:48, in ProcessSession.contingency_degradation(self)
#      46 pre = []
#      47 for session_id in self.pre:
# ---> 48     d = np.load(os.path.join(self.root_dir,
#      49                              self.animal_id,
#      50                              session_id,
#      51                              'results/intra_session_reward_hits_per_minute.npy'
#      52                              ))
#      53     pre.append(d.mean())
#      55 print (pre)
#
# File ~/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/cat/4TB/donato/andres/Cohort 6 Data/DON-013392/20230131/results/intra_session_reward_hits_per_minute.npy'

# %%
########################################################
########### EARLY VS. LATE PER 5 MIN BLOCK #############
########################################################

#
early = ['20230131',
        '20230201',
        '20230202',
        ]
late = ['20230202',
        '20230203',
        '20230204',
       ]

#
sess.early = early
sess.late = late

#
sess.early_vs_late()

#

# %%
#############################################################
########### EARLY VS. LATE PLOTS - PER SESSION ##############
#############################################################

# same but showing averages per session
sess.early = early
sess.late = late

#
sess.early_vs_late_session()
