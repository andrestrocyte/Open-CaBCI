# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################

root_dir = '/media/cat/4TB/donato/andres/'
animal_id = 'DON-011733'
session_ids = [
    '20230127',
    '20230128',
    '20230129',
    '20230130',
    '20230131',
    '20230201',
    '20230202',
    '20230203',]


for session_id in session_ids:
    sess = ProcessSession(root_dir,
                          animal_id,
                          session_id)
    #
    sess.verbose=False
    sess.load_data()

    # this is not so interesting; may need to do more on this
    sess.show_plots = False
    
    #
    sess.process_session_traces()

    #
    sess.compute_ensemble_correlations()

    #
    sess.window_size = 60   # seconds
    sess.compute_correlograms_reward_vs_licking()


    #
    sess.min_width_event_onphase = 30
    sess.min_width_event_upphase = 5
    sess.recompute_binarization = True

    #
    sess.std_upphase = 1.0
    sess.percentile_threshold = 0.9999999
    sess.use_upphase = True
    sess.binarize_ensembles()

    #
    sess.corr_window = 60   # in seconds
    sess.compute_correlograms_ensembles_upphase()

    #
    sess.window = 600   # in seconds
    sess.compute_correlograms_ensembles_fluorescence()
    
    #
    sess.bin_width = 5 # in minutes
    sess.compute_intra_session_reward_histogram()
    
    #
    sess.bin_width = 5 # in minutes
    sess.compute_intra_session_cell_burst_histogram()

    #
    sess.compute_intra_session_cell_burst_histogram_v2()

    #
    sess.isi_width = 10
    sess.isi_bin_width = 0.250
    sess.compute_intra_session_inter_burst_interval()
    
    #break
    
print ("DONE >..")
# Out:
# Missing dictionary (early sessions... skipping)
# pearson correlation E1 cells;  0.38242612254524766
# pearson correlation E2 cells;  0.1491789886367677
# lick times:  [  55.15   55.16   55.17 ... 2555.03 2555.04 2555.05]
# # of spikes:  5649
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|███████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1383.92it/s]
# model filter: remove bleaching or trends: 100%|██████████████████████████████████████████████████████| 4/4 [00:00<00:00, 2056.28it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.3937999999998465
# threshold:  0.3382999999998526
# threshold:  0.5177999999998328
# threshold:  0.2837999999998586
# binarizing continuous traces filtered fluorescence onphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 442.34it/s]
# binarizing continuous traces filtered fluorescence upphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 416.59it/s]
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 80000)
# filtered plooted:  [-1.7215956e-03  4.3677632e-05  2.0042139e-03 ... -1.9505553e-02
#  -1.9524641e-02 -1.9540787e-02]
# binsize:  30  sample rate:  30
# DONE...
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.31052950170405946, pvalue=0.41604858168736836)
# Missing dictionary (early sessions... skipping)
# pearson correlation E1 cells;  0.05040704697499869
# pearson correlation E2 cells;  0.08706268288042615
# lick times:  [ -12.86  -12.85  -12.84 ... 2618.86 2618.87 2618.88]
# # of spikes:  72680
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 753.59it/s]
# model filter: remove bleaching or trends: 100%|███████████████████████████████████████████████████████| 4/4 [00:00<00:00, 826.55it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.29079999999985784
# threshold:  0.2504999999998623
# threshold:  0.2376999999998637
# threshold:  0.3911999999998468
# binarizing continuous traces filtered fluorescence onphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 294.53it/s]
# binarizing continuous traces filtered fluorescence upphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 234.12it/s]
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [-0.01027871 -0.00909702 -0.00778457 ... -0.05330449 -0.05336211
#  -0.05341087]
# binsize:  30  sample rate:  30
# DONE...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 57
#      55 #
#      56 sess.window = 600   # in seconds
# ---> 57 sess.compute_correlograms_ensembles_fluorescence()
#      59 #
#      60 sess.bin_width = 5 # in minutes
#
# File ~/code/bmi/analysis/utils.py:563, in ProcessSession.compute_correlograms_ensembles_fluorescence(self)
#     561 cc = []
#     562 for z in range(-self.window, self.window,1):
# --> 563     cc.append(stats.pearsonr(np.roll(t1,z), t2)[0])
#     565 cc_array[k][p]=cc
#     566 #
#     567 #print (k*4+p)
#
# File ~/.conda/envs/bmi/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4446, in pearsonr(x, y, alternative)
#    4443 # By using `astype(dtype)`, we ensure that the intermediate calculations
#    4444 # use at least 64 bit floating point.
#    4445 xm = x.astype(dtype) - xmean
# -> 4446 ym = y.astype(dtype) - ymean
#    4448 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4449 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4450 # [-5e210, 5e210, 3e200, -3e200]
#    4451 normxm = linalg.norm(xm)
#
# KeyboardInterrupt:
