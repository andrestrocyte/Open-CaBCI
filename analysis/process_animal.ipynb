# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################

root_dir = '/media/cat/4TB/donato/andres/Cohort 6 Data/'
animal_id = 'DON-014266'
session_ids = [
    #'20230127',
    #'20230128',
    #'20230129',
    #'20230130',
    '20230131',
    '20230201',
    '20230202',
    '20230203',
    '20230204',
    '20230205',
    '20230206',
    '20230207',

]


for session_id in session_ids:
    sess = ProcessSession(root_dir,
                          animal_id,
                          session_id)
    #
    sess.verbose=False
    sess.load_data()

    # this is not so interesting; may need to do more on this
    sess.show_plots = False
    
    #
    sess.process_session_traces()

    #
    sess.compute_ensemble_correlations()

    #
    sess.window_size = 60   # seconds
    sess.compute_correlograms_reward_vs_licking()


    #
    sess.min_width_event_onphase = 30
    sess.min_width_event_upphase = 5
    sess.recompute_binarization = True

    #
    sess.std_upphase = 1.0
    sess.percentile_threshold = 0.9999999
    sess.use_upphase = True
    sess.binarize_ensembles()

    #
    sess.corr_window = 60   # in seconds
    sess.compute_correlograms_ensembles_upphase()

    #
    sess.window = 600   # in seconds
    sess.compute_correlograms_ensembles_fluorescence()
    
    #
    sess.bin_width = 5 # in minutes
    sess.compute_intra_session_reward_histogram()
        
    #
    sess.show_plots=False
    sess.bin_width_mins = 5 # in minutes
    sess.compute_intra_session_reward_histogram_hist_per_minute()

    #
    sess.bin_width = 5 # in minutes
    sess.compute_intra_session_cell_burst_histogram()

    #
    sess.compute_intra_session_cell_burst_histogram_v2()

    #
    sess.isi_width = 10
    sess.isi_bin_width = 0.250
    sess.compute_intra_session_inter_burst_interval()
    
    #break
    
print ("DONE >..")
# Out:
# missing:  abs_times_ttl_read
# missing:  abs_times_ca_read
# White noise:  (20033,)
# pearson correlation E1 cells;  0.20368076744758395
# pearson correlation E2 cells;  0.2902473115071469
# lick times:  [ 709.85  709.86  709.87 ... 2999.94 2999.95 2999.96]
# # of spikes:  103343
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|██████████████████████████| 4/4 [00:00<00:00, 1245.99it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1705.00it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.1738999999998707
# threshold:  0.29079999999985784
# threshold:  0.2120999999998665
# threshold:  0.17889999999987016
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [ 0.07290722  0.08183093  0.09174173 ... -0.01740802 -0.01740095
#  -0.017395  ]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=0.8943363209720763, pvalue=0.00047920622278854123)
# Perason corr:  PearsonRResult(statistic=0.8864460666577184, pvalue=0.0006329143521010731)
# missing:  abs_times_ttl_read
# missing:  abs_times_ca_read
# White noise:  (17043,)
# pearson correlation E1 cells;  0.4556668558758855
# pearson correlation E2 cells;  0.5311285128779933
# lick times:  [  49.45   49.46   49.47 ... 2999.95 2999.96 2999.97]
# # of spikes:  211627
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|███████████████████████████| 4/4 [00:00<00:00, 851.42it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1565.18it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.3102999999998557
# threshold:  0.2747999999998596
# threshold:  0.2809999999998589
# threshold:  0.29509999999985737
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [ 0.00609507  0.01031745  0.01500685 ... -0.00047607 -0.00048187
#  -0.00048673]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.6440873270360821, pvalue=0.04443960939900605)
# Perason corr:  PearsonRResult(statistic=-0.6229794087187025, pvalue=0.05434830938168293)
# missing:  abs_times_ttl_read
# missing:  abs_times_ca_read
# White noise:  (13460,)
# pearson correlation E1 cells;  0.035357705852172
# pearson correlation E2 cells;  -0.0013840641470419662
# lick times:  [  -4.24   -4.23   -4.22 ... 2999.96 2999.97 2999.98]
# # of spikes:  77133
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|███████████████████████████| 4/4 [00:00<00:00, 804.12it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1134.75it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.1822999999998698
# threshold:  0.31689999999985496
# threshold:  0.16639999999987154
# threshold:  0.1395999999998745
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [-0.0063694  -0.00601001 -0.00561086 ... -0.01612632 -0.01611284
#  -0.01610145]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=0.08910591312487201, pvalue=0.8066210879575384)
# Perason corr:  PearsonRResult(statistic=0.17558196284520222, pvalue=0.6275380194985116)
# missing:  abs_times_ttl_read
# missing:  abs_times_ca_read
# White noise:  (18837,)
# pearson correlation E1 cells;  0.07177909379182656
# pearson correlation E2 cells;  0.015262446876218272
# lick times:  [ 203.86  203.87  203.88 ... 2997.95 2997.96 2997.97]
# # of spikes:  75410
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|██████████████████████████| 4/4 [00:00<00:00, 1368.45it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1838.60it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.13619999999987487
# threshold:  0.16009999999987223
# threshold:  0.14469999999987393
# threshold:  0.20189999999986763
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [-0.03614838 -0.03634943 -0.03657275 ... -0.0130293  -0.01302692
#  -0.01302487]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.21759706994462236, pvalue=0.5459109308521766)
# Perason corr:  PearsonRResult(statistic=-0.1734904562983542, pvalue=0.6317076749933278)
# missing:  abs_times_ttl_read
# missing:  abs_times_ca_read
# White noise:  (13012,)
# pearson correlation E1 cells;  0.20201931779902924
# pearson correlation E2 cells;  0.45384731040098225
# lick times:  [ 204.56  204.57  204.58 ... 2925.76 2925.77 2925.78]
# # of spikes:  50507
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|██████████████████████████| 4/4 [00:00<00:00, 1379.59it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1071.96it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.16439999999987176
# threshold:  0.23149999999986437
# threshold:  0.12219999999987641
# threshold:  0.1331999999998752
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [ 0.03097401  0.03511632  0.03971686 ... -0.02515317 -0.02516178
#  -0.0251691 ]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=0.417670053281719, pvalue=0.22974222243140385)
# Perason corr:  PearsonRResult(statistic=0.5296950717690522, pvalue=0.11532445394492676)
# White noise:  (17342,)
# pearson correlation E1 cells;  0.07552452871472365
# pearson correlation E2 cells;  0.03716883329747278
# lick times:  [  -3.01   -3.     -2.99 ... 2877.75 2877.76 2877.77]
# # of spikes:  56174
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|██████████████████████████| 4/4 [00:00<00:00, 1340.57it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1851.59it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.09619999999987927
# threshold:  0.12939999999987561
# threshold:  0.08109999999988093
# threshold:  0.08259999999988077
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [-0.00529502 -0.00408966 -0.00275098 ... -0.02153328 -0.02441051
#  -0.02724308]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.61215550030408, pvalue=0.05995380540629257)
# Perason corr:  PearsonRResult(statistic=-0.6147332543462328, pvalue=0.05858579578698084)
# White noise:  (9867,)
# pearson correlation E1 cells;  0.009187155007982093
# pearson correlation E2 cells;  0.030534228780581995
# lick times:  [  -4.27   -4.26   -4.25 ... 2985.26 2985.27 2985.28]
# # of spikes:  70011
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|██████████████████████████| 4/4 [00:00<00:00, 1295.84it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1876.65it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.1820999999998698
# threshold:  0.1640999999998718
# threshold:  0.11349999999987737
# threshold:  0.0977999999998791
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [ 0.00028355  0.00092879  0.00164541 ... -0.01745935 -0.01795567
#  -0.01809964]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.38888208221874054, pvalue=0.26671523762711674)
# Perason corr:  PearsonRResult(statistic=-0.33043699079237027, pvalue=0.3510577843653342)
# White noise:  (12827,)
# pearson correlation E1 cells;  0.01407546816914977
# pearson correlation E2 cells;  0.009339619461678671
# lick times:  [ 123.39  123.4   123.41 ... 2881.98 2881.99 2882.  ]
# # of spikes:  8874
# binsize:  1  sample rate:  1
# DONE...
# low pass filter: 100%|███████████████████████████| 4/4 [00:00<00:00, 858.78it/s]
# model filter: remove bleaching or trends: 100%|█| 4/4 [00:00<00:00, 1755.49it/s]
# too few cells... for std global, saving individual stds : (4,)
# fitting guassian to compute f0:...
# threshold:  0.2592999999998613
# threshold:  0.23159999999986436
# threshold:  0.10569999999987822
# threshold:  0.11819999999987685
# binarizing continuous traces filtered fluorescence onphase: 100%|█| 4/4 [00:00<0
# binarizing continuous traces filtered fluorescence upphase: 100%|█| 4/4 [00:00<0
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)
# filtered plooted:  [-0.00373891 -0.00282329 -0.00180638 ...  0.14057449  0.147753
#   0.1553056 ]
# binsize:  30  sample rate:  30
# DONE...
# /home/cat/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# DONE...
# Perason corr:  PearsonRResult(statistic=-0.24082406492091707, pvalue=0.5027014458504999)
# Perason corr:  PearsonRResult(statistic=-0.23326019590962283, pvalue=0.5166119282156192)
# DONE >..

# %%
/media/cat/4TB/donato/andres/Cohort 6 Data/DON014266/20230131/results
/media/cat/4TB/donato/andres/Cohort 6 Data/DON-014266/20230131/results
