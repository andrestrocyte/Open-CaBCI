# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession, ProcessCohort
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################


root_dir = '/media/cat/4TB/donato/andres/Cohort 6 Data/'
cohort_name = "cohort6"
animal_ids = [
    'DON-011733',
    'DON-012503',
    'DON-013392',
    'DON-014266'
]

#
coh = ProcessCohort(root_dir,
                    animal_ids,
                   cohort_name)
coh.verbose=False
coh.show_plots=True

# %%
#
coh.cohort_hit_rate()
