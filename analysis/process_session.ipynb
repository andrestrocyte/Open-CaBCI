# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds

# %%
####################################################
################## LOAD DATA #######################
####################################################

root_dir = '/media/cat/4TB/donato/andres/'
animal_id = 'DON-012503'
session_id = '20230202'

        
sess = ProcessSession(root_dir,
                      animal_id,
                      session_id)
#
sess.load_data()
# Out:
# sample rate:  30
# reward times:  (113,)
# abs times:  (3005758,) [ 163.6778394  163.6780203  163.6781784 ... 3167.3839359 3167.3855663
#  3167.3857579]
# ttl times:  (89953,) 167.4196949 3167.3857579  total rec time sec:  2999.966063
# ttl computed:  (89953,) [    0     1     2 ... 89997 89998 89999]
# ttl detected:  (89953, 1)
# lick detector:  (3005758, 1)
# lick times:  [   3.1840943    3.1842865    3.1860682 ... 2985.9843025 2985.9846362
#  2985.9862498]
# (90000,)
# E1 , E2,  (2, 90000) (2, 90000)
# Recording length (mins):  50.0
# DONE...

# %%
############################################################
############# PLOTS IN HONOR OF CAJAL AND RY ###############
############################################################
sess.show_session_traces()

# %%
#################################################################
############# CORRELOGRAMS BETWEEN REWARDS AND LICKING ##########
#################################################################
# this is not so interesting; may need to do more on this
sess.compute_ensemble_correlations()

#
sess.window_size = 60   # seconds
sess.compute_correlograms_reward_vs_licking()
# Out:
# pearson correlation E1 cells;  0.03916222897242536
# pearson correlation E2 cells;  0.09556712722981311
# binsize:  1  sample rate:  1
# DONE...

# %%
########################################################
############# BINARIZE THE [CA] TRACES #################
########################################################

# double check that we have set the STD thrshold at a reasonable level to catch biggest/highest SNR bursts
sess.std_upphase = 3.0
sess.binarize_ensembles()
# Out:
# low pass filter: 100%|███████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1322.39it/s]
# model filter: remove bleaching or trends: 100%|██████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1751.64it/s]
# too few cells... for std global, saving individual stds : (4,)
# binarizing continuous traces filtered fluorescence onphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 514.28it/s]
# binarizing continuous traces filtered fluorescence upphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 404.06it/s]
#    Oasis based binarization skipped by default ...
# low pass filter: 100%|███████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1330.15it/s]
# model filter: remove bleaching or trends: 100%|██████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1937.55it/s]
# too few cells... for std global, saving individual stds : (4,)
# binarizing continuous traces filtered fluorescence onphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 647.09it/s]
# binarizing continuous traces filtered fluorescence upphase: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 414.87it/s]
#    Oasis based binarization skipped by default ...
# Binarized traces:  (4, 90000)

# %%
###################################################################################
############COMPUTE CORRELOGRAMS BETWEEN CELLS BASED ON UPPHASE DETECTION #########
###################################################################################
#
sess.corr_window = 60   # in seconds
sess.compute_correlograms_ensembles_upphase()
# Out:
# spike times:  [  10.5          10.53333333   10.96666667 ... 2979.76666667 2979.8
#  2979.83333333]
# binsize:  30  sample rate:  30
# (4, 4, 61)
# DONE...

# %%
###########################################################################################
############COMPUTE CORRELOGRAMS BETWEEN CELLS BASED ON RAW FILTERED FLUORESCENCE #########
##########################################################################################
#
sess.window = 600   # in seconds
sess.compute_correlograms_ensembles_fluorescence()
# Out:
# DONE...

# %%
########################################################
####### COMPUTE INTRA-SESSION REWARD HISTOGRAM #########
########################################################

#
sess.bin_width = 5 # in minutes
sess.compute_intra_session_reward_histogram()
# Out:
# Perason corr:  PearsonRResult(statistic=0.3706110830816283, pvalue=0.2917649089674079)

# %%
##########################################################################
####### COMPUTE INTRA-SESSION CELL BURST HISTOGRAMS AS LINE PLOT #########
##########################################################################

#
sess.bin_width = 5 # in minutes
sess.compute_intra_session_cell_burst_histogram()

# %%
##########################################################################
####### COMPUTE INTRA-SESSION CELL BURST HISTOGRAMS AS LINE PLOT #########
##########################################################################
#
sess.compute_intra_session_cell_burst_histogram_v2()

# %%
####################################################
####### INTER-BURST-INTERVAL DISTRIBUTIONS #########
####################################################
#
sess.isi_width = 10
sess.isi_bin_width = 0.250
sess.compute_intra_session_inter_burst_interval()
