# %%
# %autosave 180
# %load_ext autoreload
# %autoreload 2

# import matplotlib
# #matplotlib.use('qtagg')
# %matplotlib tk
# import matplotlib.pyplot as plt
# plt.ion()
# %matplotlib notebook

#|
import os
import numpy as np
import time
import nidaqmx
from nidaqmx.constants import (AcquisitionType)  # https://nidaqmx-python.readthedocs.io/en/latest/constants.html
import numpy as np
import matplotlib.pyplot as plt
from nidaqmx.constants import TerminalConfiguration
import math
from multiprocessing import Process

#
# Out:
# Autosaving every 180 seconds

# %%
import tifffile as tiff
import numpy as np

fname = '/media/cat/4TB1/donato/DON-10914/calibration/Image_001_001.raw'
data = np.fromfile(fname,dtype=np.uint16).reshape(-1,512,512)
print (data.shape)

#
tiff.imwrite(fname.replace('.raw','.tiff'),data)
# Out:
# (20000, 512, 512)

# %%
smb://scicore-toucan.scicore.unibas.ch/donafl00-calcium$/Users/Steffen/Experiments/DON-009191/20220219/002P-F/DON-009191_20220219_002P-F_S1-S2.mesc
                  /scicore/projects/donafl00-calcium/Users/Steffen/Experiments/DON-009191/20220219/002P-F/DON-009191_20220219_002P-F_S1-S2-ACQ.mesc
