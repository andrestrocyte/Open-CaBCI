# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os

import os

from utils_behavior import ProcessSession
# Out:
# Autosaving every 180 seconds

# %%
####################################################
################## LOAD DATA #######################
####################################################


root_dir = r'Z:\RG Donato\Microscopy\Renan\BMI_analysis\cohort10'
#root_dir = '/media/cat/4TB/donato/andres/'

root_dir = '/media/cat/8TB/donato/bmi/master_analysis'

animal_id = 'DON-014382'
#

#
sess = ProcessSession(root_dir,
                      animal_id)
#
sess.verbose=False

#

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()

print ("DONE >..")
# Out:
# Loading n_rewards_per_session.npy
# loading data for n_rewards_per_session: 100%|██████████| 8/8 [00:00<00:00, 129055.51it/s]
# xx:  [0 1 2 3 4 5 6 7]
# yy:  [31 47 51 49 57 49 59 43]
# DONE >..

# %%
######################################################
############### SHOW HIT RATES / SESSION #############
######################################################

#
sess.show_plots=True
sess.hit_rate_per_session()

print ("DONE >..")
# Out:
# loading data for hit rate per session:   0%|          | 0/8 [00:00<?, ?it/s]
# loading data for hit rate per session: 100%|██████████| 8/8 [00:00<00:00, 4802.41it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.session_id = 1
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# Loading data...
#     ... done loading data...
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Loading data...
# Could not load file:  /media/cat/8TB/donato/bmi/master_analysis/DON-014382/day0/data/results.npz
#     ... done loading data...
# Loading data...
#  22%|██▏       | 2/9 [00:06<00:22,  3.28s/it]
#     ... done loading data...
# Loading data...
#  33%|███▎      | 3/9 [00:12<00:26,  4.49s/it]
#     ... done loading data...
# Loading data...
#  44%|████▍     | 4/9 [00:19<00:26,  5.20s/it]
#     ... done loading data...
# Loading data...
#  56%|█████▌    | 5/9 [00:25<00:22,  5.57s/it]
#     ... done loading data...
# Loading data...
#  67%|██████▋   | 6/9 [00:31<00:17,  5.82s/it]
#     ... done loading data...
# Loading data...
#  78%|███████▊  | 7/9 [00:38<00:12,  6.06s/it]
#     ... done loading data...
# Loading data...
#  89%|████████▉ | 8/9 [00:44<00:06,  6.11s/it]
#     ... done loading data...
# Loading data...
# 100%|██████████| 9/9 [00:51<00:00,  5.67s/it]
#     ... done loading data...

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# loading data for n_bursts_per_session: 100%|██████████| 8/8 [00:00<00:00, 374.77it/s]
# DONE >..

# %%
######################################################
########### EVOLUTION OF CELL-XCORRELOGRAMS ##########
######################################################

#
sess.verbose=False
sess.window = 30   # in seconds
sess.correlograms_inter_session()
# Out:
# loading data for hit rate per session:   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 8
#       6 sess.verbose=False
#       7 sess.window = 30   # in seconds
# ----> 8 sess.correlograms_inter_session()
#
# File ~/code/bmi/analysis/behavior/utils_behavior.py:1864, in ProcessSession.correlograms_inter_session(self)
#    1860 ctr_sess =0
#    1861 for session_id in tqdm(self.session_ids[1:], desc='loading data for hit rate per session'):
#    1862
#    1863     #
# -> 1864     cc = np.load(os.path.join(self.root_dir,
#    1865                               self.animal_id,
#    1866                               session_id,
#    1867                               'results',
#    1868                               'correlograms_fluorescence.npy'), allow_pickle=True)
#    1869    # print ("cc : ", cc)
#    1870     print ("Length of cc: ", len(cc), len(cc[0]))
#
# File ~/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/cat/8TB/donato/bmi/master_analysis/DON-014382/20230408/results/correlograms_fluorescence.npy'

# %%
########################################################
########### CONTINGENCY DEGRADATION PLOTS ##############
########################################################

#

#
sess.contingency_degradation()

#

# %%
########################################################
########### EARLY VS. LATE PER 5 MIN BLOCK #############
########################################################


#
sess.early_vs_late()

#
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 7>()
#       1 ########################################################
#       2 ########### EARLY VS. LATE PER 5 MIN BLOCK #############
#       3 ########################################################
#       4
#       5
#       6 #
# ----> 7 sess.early_vs_late()
#
# File C:\code\bmi_working\analysis\utils.py:612, in ProcessSession.early_vs_late(self)
#     608 def early_vs_late(self):
#     609
#     610     # load test data
#     611     early = []
# --> 612     for session_id in self.early:
#     613         d = np.load(os.path.join(self.root_dir,
#     614                                  self.animal_id,
#     615                                  session_id,
#     616                                  'results/intra_session_reward_hits_per_minute.npy'
#     617                                  ))
#     618         early.append(d)
#
# AttributeError: 'ProcessSession' object has no attribute 'early'

# %%
#############################################################
########### EARLY VS. LATE PLOTS - PER SESSION ##############
#############################################################
#
sess.early_vs_late_session()

# %%
#############################################################
########### TIME TO REWARD EARLY VS. LATE ###################
#############################################################

#
sess.time_to_reward_per_trial_inter_session_late_vs_early()

# %%
###########################################
####### BINNED PAIRWISE CORRELATIONS ######
###########################################

#
#sess.session_id = '20230202'
#sess.session_id = '20230131'
sess.pairwise_correlations_inter_session_dff()

# %%
'/media/cat/4TB/donato/andres/DON-011733/20230127/pairwise_correlations_intra_session_upphase.npz'
'/media/cat/4TB/donato/andres/DON-011733/20230127/results/pairwise_correlations_intra_session_upphase.npz'
