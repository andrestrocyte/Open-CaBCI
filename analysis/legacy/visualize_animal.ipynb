# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2


import numpy as np
#%matplotlib inline
import os
from utils import *

import os

from utils import ProcessSession
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
####################################################
################## LOAD DATA #######################
####################################################


root_dir = r'Z:\RG Donato\Microscopy\Andres\BMI Project\cohort8'
root_dir = '/media/cat/4TB/donato/andres/cohort8/'
#animal_id = 'DON-011733'
animal_id = 'DON-014265'
session_ids = [
    '20230329',
    '20230330',
    '20230331',
    '20230401',
    '20230402',
    '20230403',
]


#
sess = ProcessSession(root_dir,
                      animal_id,
                      session_ids[0])

#
sess.verbose=False
sess.session_ids = session_ids

# %%
######################################################
############### SHOW N-REWARDS / SESSION #############
######################################################

#
sess.n_rewards_per_session()

print ("DONE >..")
# Out:
# loading data for n_rewards_per_session: 100%|██████████| 6/6 [00:18<00:00,  3.14s/it]
# xx:  [0 1 2 3 4 5]
# yy:  [34 34 14  9 31 58]
# DONE >..

# %%
######################################################
############### SHOW HIT RATES / SESSION #############
######################################################

#
sess.show_plots=True
sess.hit_rate_per_session()

print ("DONE >..")
# Out:
# loading data for hit rate per session:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       1 ######################################################
#       2 ############### SHOW HIT RATES / SESSION #############
#       3 ######################################################
#       4
#       5 #
#       6 sess.show_plots=True
# ----> 7 sess.hit_rate_per_session()
#       9 print ("DONE >..")
#
# File ~/code/bmi/analysis/utils.py:1599, in ProcessSession.hit_rate_per_session(self)
#    1595 hit_rates = []
#    1596 for session_id in tqdm(self.session_ids, desc='loading data for hit rate per session'):
#    1597
#    1598     #
# -> 1599     hr = np.load(os.path.join(self.root_dir,
#    1600                               self.animal_id,
#    1601                              session_id,
#    1602                              'results',
#    1603                              'intra_session_reward_hits_per_minute.npy'))
#    1605     #
#    1606     hit_rates.append(hr)
#
# File ~/.conda/envs/bmi/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/cat/4TB/donato/andres/cohort8/DON-014265/20230329/results/intra_session_reward_hits_per_minute.npy'

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.n_rewards_intra_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
######################################################
########### AVERAGE REWARDS INTRASESSION #############
######################################################

#
sess.verbose=False
sess.n_rewards_intra_session_normalized()

#
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:19<00:00,  2.42s/it]
# Perason corr:  PearsonRResult(statistic=0.6034571654660679, pvalue=0.0647247527066569)

# %%
######################################################
########### EVOLUTION OF CELL-XCORRELOGRAMS ##########
######################################################

#

sess.verbose=False
sess.window = 20*30   # in seconds
sess.correlograms_inter_session()
# Out:
# loading data for hit rate per session:  29%|████████████▌                               | 2/7 [00:00<00:00, 10.28it/s]
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# loading data for hit rate per session: 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 29.60it/s]
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4
# Length of cc:  4 4

# %%
######################################################
############### SHOW N-BURSTS / SESSION ##############
######################################################

#
sess.n_bursts_per_session()

#
print ("DONE >..")
# Out:
# DONE >..

# %%
########################################################
########### CONTINGENCY DEGRADATION PLOTS ##############
########################################################

#
t = [ '20230329',
    '20230330']
cd = [ '20230401',
    '20230402',]
r = [  '20230402',
    '20230403']

sess.pre = t
sess.during = cd
sess.post = r

#
sess.contingency_degradation()

#

# %%
########################################################
########### EARLY VS. LATE PER 5 MIN BLOCK #############
########################################################

#
early = ['20230131',
        '20230201',
        '20230202',
        ]
late = ['20230202',
        '20230203',
        '20230204',
       ]

#
sess.early = early
sess.late = late

#
sess.early_vs_late()

#

# %%
#############################################################
########### EARLY VS. LATE PLOTS - PER SESSION ##############
#############################################################

# same but showing averages per session
sess.early = early
sess.late = late

#
sess.early_vs_late_session()
